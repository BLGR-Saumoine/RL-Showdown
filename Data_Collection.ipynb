# %%
from extracData import getPoolOfInfos, list_to_dict_ID, WEATHER_TO_ID, TERRAIN_TO_ID, STATUS_TO_ID, POKE_ID, MOVES_ID, ABILITIES_ID, ITEMS_ID
import json
import requests
#from manageBattle import is_clean_match, to_pokeenv_id

# %% [markdown]
# # Feature engineering

# %%
from feature_engineering import get_items_json
get_items_json("FE_datas/items")
# Out:
# []

# %%
response = requests.get(f'https://pokeapi.co/api/v2/item/heavy-duty-boots/')

temp = response.json()
temp

# %%
temp.get("flavor_text_entries", "yooo man")
# Out:
# [{'language': {'name': 'ja-hrkt',
#    'url': 'https://pokeapi.co/api/v2/language/1/'},
#   'text': 'おおむかしの\u3000えいゆうが\u3000さいやくを\nうちはらったと\u3000つたえられる\u3000たて\u3000だが\nいまは\u3000さびて\u3000ボロボロに\u3000なっている。',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#   'text': '먼 옛날의 영웅이 재앙을 막는 데\n사용했다고 전해지는 방패지만\n지금은 녹이 슬고 닳아버렸다.',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'zh-hant',
#    'url': 'https://pokeapi.co/api/v2/language/4/'},
#   'text': '據說在很久以前，英雄就是\n用這面盾來擊退災厄。\n但現在已經生鏽，變得破爛不堪。',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#   'text': 'On raconte que ce bouclier fut jadis utilisé\npar un héros pour vaincre une calamité.\nÀ présent, il est tout usé et rouillé.',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#   'text': 'Mit diesem Schild soll ein Held einstmals großes Unheil\nabgewendet haben. Rost sowie der Zahn der Zeit haben\njedoch ihre Spuren hinterlassen.',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#   'text': 'Cuenta una antigua leyenda que un valiente héroe\nasió este escudo para hacer frente a un cataclismo,\npero ahora está oxidado y en un estado lamentable.',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#   'text': 'Si racconta che in passato un eroe riuscì a respingere\nla calamità servendosi di questo scudo. Ora è tutto\narrugginito e rovinato.',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#   'text': 'It is said that a hero used this shield to halt a terrible\ndisaster in ancient times. But it’s grown rusty and worn.',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#   'text': '大昔の\u3000英雄が\u3000災厄を\n討ち払ったと\u3000伝えられる\u3000盾\u3000だが\nいまは\u3000さびて\u3000ボロボロに\u3000なっている。',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#  {'language': {'name': 'zh-hans',
#    'url': 'https://pokeapi.co/api/v2/language/12/'},
#   'text': '据说很久以前，英雄就是\n拿着这面盾驱走了灾厄。\n而现在早已变得锈迹斑斑。',
#   'version_group': {'name': 'sword-shield',
#    'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]

# %%
temp["effect_entries"]
# Out:
# [{'effect': 'Augmente la Défense Spéciale du porteur de 1.5x.  Empêche le porteur de sélectionner des capacités de statut.',
#   'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#   'short_effect': 'Augmente la Défense Spéciale du porteur de 1.5x.  Empêche le porteur de sélectionner des capacités de statut.'},
#  {'effect': 'Raises the holder’s Special Defense to 1.5×.  Prevents the holder from selecting a status move.',
#   'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#   'short_effect': 'Raises the holder’s Special Defense to 1.5×.  Prevents the holder from selecting a status move.'}]

# %%
dict_moves = {}
for move, id in ABILITIES_ID.items() :
    print(move,id)
# Out:
# unknown 0
# Triage 1
# Electromorphosis 2
# Light Metal 3
# Zero to Hero 4
# Contrary 5
# Limber 6
# Hadron Engine 7
# Stakeout 8
# Defiant 9
# Tablets of Ruin 10
# Water Absorb 11
# Scrappy 12
# Unaware 13
# Cloud Nine 14
# Liquid Voice 15
# Keen Eye 16
# Technician 17
# Water Veil 18
# Filter 19
# Fur Coat 20
# Bulletproof 21
# Tangling Hair 22
# Frisk 23
# Grassy Surge 24
# Ice Scales 25
# Shell Armor 26
# Intimidate 27
# Huge Power 28
# Synchronize 29
# Sheer Force 30
# Sand Rush 31
# Swift Swim 32
# Berserk 33
# Gale Wings 34
# Fluffy 35
# Queenly Majesty 36
# Mega Launcher 37
# Serene Grace 38
# Poison Touch 39
# Prism Armor 40
# Soundproof 41
# Grim Neigh 42
# Prankster 43
# Galvanize 44
# Big Pecks 45
# Rocky Payload 46
# Slush Rush 47
# Effect Spore 48
# Own Tempo 49
# Sturdy 50
# Soul-Heart 51
# Analytic 52
# Mirror Armor 53
# Cursed Body 54
# Chlorophyll 55
# Overcoat 56
# Earth Eater 57
# Competitive 58
# Tough Claws 59
# Static 60
# Sand Force 61
# Air Lock 62
# Vessel of Ruin 63
# Skill Link 64
# As One (Spectrier) 65
# Reckless 66
# Good as Gold 67
# Sharpness 68
# No Guard 69
# Truant 70
# Shields Down 71
# Pressure 72
# Leaf Guard 73
# Protean 74
# Overgrow 75
# Infiltrator 76
# Sand Stream 77
# Volt Absorb 78
# Toxic Boost 79
# Slow Start 80
# Justified 81
# Magnet Pull 82
# Orichalcum Pulse 83
# Strong Jaw 84
# Guts 85
# Surge Surfer 86
# Toxic Debris 87
# Tera Shift 88
# Stamina 89
# Unburden 90
# Quark Drive 91
# Unnerve 92
# Thick Fat 93
# Protosynthesis 94
# Pixilate 95
# Illusion 96
# Solid Rock 97
# Purifying Salt 98
# Inner Focus 99
# Multiscale 100
# Dauntless Shield 101
# Insomnia 102
# Corrosion 103
# Tinted Lens 104
# Sniper 105
# Drizzle 106
# Shield Dust 107
# Mold Breaker 108
# Cheek Pouch 109
# Pickpocket 110
# Adaptability 111
# Water Compaction 112
# Ice Body 113
# Quick Feet 114
# Levitate 115
# Seed Sower 116
# Mind's Eye 117
# Aroma Veil 118
# Hunger Switch 119
# Bad Dreams 120
# Thermal Exchange 121
# Unseen Fist 122
# Liquid Ooze 123
# Swarm 124
# Mycelium Might 125
# Compound Eyes 126
# Oblivious 127
# Full Metal Body 128
# Magic Bounce 129
# Battle Bond 130
# Clear Body 131
# Punk Rock 132
# Water Bubble 133
# Hydration 134
# Poison Heal 135
# Damp 136
# Toxic Chain 137
# Hustle 138
# Imposter 139
# Cute Charm 140
# Multitype 141
# Heavy Metal 142
# Heatproof 143
# Moxie 144
# Natural Cure 145
# Dancer 146
# Vital Spirit 147
# Rock Head 148
# Well-Baked Body 149
# Sticky Hold 150
# Shed Skin 151
# Harvest 152
# Beads of Ruin 153
# Torrent 154
# Aftermath 155
# Arena Trap 156
# Disguise 157
# Rough Skin 158
# Dry Skin 159
# Intrepid Sword 160
# As One (Glastrier) 161
# Chilling Neigh 162
# Pure Power 163
# Power Spot 164
# Flame Body 165
# Turboblaze 166
# Poison Puppeteer 167
# Download 168
# Libero 169
# Gulp Missile 170
# Anger Shell 171
# Drought 172
# Dragon's Maw 173
# Sword of Ruin 174
# Rattled 175
# Teravolt 176
# Gooey 177
# Weak Armor 178
# Shadow Tag 179
# Sap Sipper 180
# Magic Guard 181
# Speed Boost 182
# Electric Surge 183
# Trace 184
# Comatose 185
# Iron Fist 186
# Lightning Rod 187
# Ice Face 188
# Regenerator 189
# Psychic Surge 190
# Wind Rider 191
# Transistor 192
# Flash Fire 193
# Blaze 194
# Storm Drain 195
# Flower Veil 196
# Motor Drive 197
# Supreme Overlord 198
# Cud Chew 199
# Snow Warning 200
# Early Bird 201
# Magician 202
# Shadow Shield 203

# %%
dict_moves = {}
for move in MOVES_ID.keys() :
    if move != "unknown" :
        temp = move.replace(' ', '-')
        response = requests.get(f'https://pokeapi.co/api/v2/move/{temp}/')
        print(move)
        print(response.json())

# %%
response = requests.get(f'https://pokeapi.co/api/v2/move/Will-O-Wisp/')

temp = response.json()
temp
# Out:
# {'accuracy': 85,
#  'contest_combos': {'normal': {'use_after': [{'name': 'sunny-day',
#      'url': 'https://pokeapi.co/api/v2/move/241/'}],
#    'use_before': None},
#   'super': {'use_after': None, 'use_before': None}},
#  'contest_effect': {'url': 'https://pokeapi.co/api/v2/contest-effect/4/'},
#  'contest_type': {'name': 'beauty',
#   'url': 'https://pokeapi.co/api/v2/contest-type/2/'},
#  'damage_class': {'name': 'status',
#   'url': 'https://pokeapi.co/api/v2/move-damage-class/1/'},
#  'effect_chance': None,
#  'effect_changes': [],
#  'effect_entries': [{'effect': 'Brûle la cible.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'short_effect': 'Brûle la cible.'},
#   {'effect': 'Burns the target.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'short_effect': 'Burns the target.'}],
#  'flavor_text_entries': [{'flavor_text': 'Inflicts a burn on the foe\nwith intense fire.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'ruby-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/5/'}},
#   {'flavor_text': 'Inflicts a burn on the foe\nwith intense fire.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'emerald',
#     'url': 'https://pokeapi.co/api/v2/version-group/6/'}},
#   {'flavor_text': 'A sinister, bluish\nwhite flame is shot\nat the foe to\ninflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'firered-leafgreen',
#     'url': 'https://pokeapi.co/api/v2/version-group/7/'}},
#   {'flavor_text': 'The user shoots a\nsinister, bluish white\nflame at the foe to\ninflict a burn.\n',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'diamond-pearl',
#     'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#   {'flavor_text': 'The user shoots a\nsinister, bluish white\nflame at the foe to\ninflict a burn.\n',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'platinum',
#     'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#   {'flavor_text': 'The user shoots a\nsinister, bluish white\nflame at the foe to\ninflict a burn.\n',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'heartgold-soulsilver',
#     'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#   {'flavor_text': 'Lance une sinistre flamme violette à\nl’ennemi pour lui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'black-white',
#     'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#   {'flavor_text': 'The user shoots a sinister, bluish-white\nflame at the target to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'black-white',
#     'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#   {'flavor_text': 'The user shoots a sinister, bluish-white\nflame at the target to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'black-2-white-2',
#     'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#   {'flavor_text': 'ぶきみで\u3000あやしい\u3000ほのおを\u3000はなって\nあいてを\u3000やけどの\u3000じょうたいに\u3000する。\n',
#    'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': '으스스하고 괴상한 불꽃을 쏘아\n상대를 화상 상태로 만든다.',
#    'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': 'Lance une sinistre flamme violette à l’ennemi pour\nlui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': 'Angriff mit unheimlicher Flamme,\ndie das Ziel verbrennt.',
#    'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': 'Siniestra llama morada que produce quemaduras.',
#    'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': 'Fiamme intense di colore viola causano\nuna scottatura al bersaglio.',
#    'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': 'The user shoots a sinister, bluish-white\nflame at the target to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': '不気味で\u3000怪しい\u3000炎を\u3000放って\n相手を\u3000やけどの\u3000状態に\u3000する。\n',
#    'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'flavor_text': 'ぶき\u202fで\u3000あやしい\u3000ほのおを\u3000はなって\nあいてを\u3000やけどの\u3000じょうたいに\u3000する。\n',
#    'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': '으스스하고 괴상한 불꽃을 쏘아\n상대를 화상 상태로 만든다.',
#    'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': 'Lance une sinistre flamme violette à l’ennemi pour\nlui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': 'Angriff mit unheimlicher Flamme,\ndie das Ziel verbrennt.',
#    'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': 'Siniestra llama morada que produce quemaduras. ',
#    'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': 'Fiamme intense di colore viola causano\nuna scottatura al bersaglio.',
#    'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': 'The user shoots a sinister, bluish-white\nflame at the target to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': '不気味で\u3000怪しい\u3000炎を\u3000放って\n相手を\u3000やけどの\u3000状態に\u3000する。\n',
#    'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'flavor_text': 'ぶきみで\u3000あやしい\u3000ほのおを\u3000はなって\nあいてを\u3000やけどの\u3000じょうたいに\u3000する。',
#    'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': '으스스하고 괴상한 불꽃을 쏘아\n상대를 화상 상태로 만든다.',
#    'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': '放出詭異的火焰，\n讓對手陷入灼傷狀態。',
#    'language': {'name': 'zh-hant',
#     'url': 'https://pokeapi.co/api/v2/language/4/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': 'Lance un bouquet de flammes maléfiques à l’ennemi\npour lui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': 'Angriff mit unheimlicher Flamme, die beim Ziel\nVerbrennungen verursacht.',
#    'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': 'Siniestra llama morada que produce quemaduras. ',
#    'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': 'Fiamme intense di colore viola causano\nuna scottatura al bersaglio.',
#    'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': 'The user shoots a sinister, bluish-white flame at the\ntarget to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': '不気味で\u3000怪しい\u3000炎を\u3000放って\n相手を\u3000やけどの\u3000状態に\u3000する。',
#    'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': '放出怪异的火焰，\n从而让对手陷入灼伤状态。',
#    'language': {'name': 'zh-hans',
#     'url': 'https://pokeapi.co/api/v2/language/12/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'flavor_text': 'ぶきみで\u3000あやしい\u3000ほのおを\u3000はなって\nあいてを\u3000やけどの\u3000じょうたいに\u3000する。',
#    'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': '으스스하고 괴상한 불꽃을 쏘아\n상대를 화상 상태로 만든다.',
#    'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': '放出詭異的火焰，\n讓對手陷入灼傷狀態。',
#    'language': {'name': 'zh-hant',
#     'url': 'https://pokeapi.co/api/v2/language/4/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': 'Lance un bouquet de flammes maléfiques à l’ennemi\npour lui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': 'Angriff mit unheimlicher Flamme, die beim Ziel\nVerbrennungen verursacht.',
#    'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': 'Siniestra llama morada que produce quemaduras. ',
#    'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': 'Fiamme intense di colore viola causano\nuna scottatura al bersaglio.',
#    'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': 'The user shoots a sinister, bluish-white flame at the\ntarget to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': '不気味で\u3000怪しい\u3000炎を\u3000放って\n相手を\u3000やけどの\u3000状態に\u3000する。',
#    'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': '放出怪异的火焰，\n从而让对手陷入灼伤状态。',
#    'language': {'name': 'zh-hans',
#     'url': 'https://pokeapi.co/api/v2/language/12/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'flavor_text': 'ぶきみで\u3000あやしい\u3000ほのおを\u3000はなって\nあいてを\u3000やけどの\u3000じょうたいに\u3000する。',
#    'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': '으스스하고 괴상한 불꽃을 쏘아\n상대를 화상 상태로 만든다.',
#    'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': '放出詭異的火焰，\n讓對手陷入灼傷狀態。',
#    'language': {'name': 'zh-hant',
#     'url': 'https://pokeapi.co/api/v2/language/4/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': 'Lance un bouquet de flammes maléfiques à l’ennemi\npour lui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': 'Angriff mit unheimlicher Flamme, die beim Ziel\nVerbrennungen verursacht.',
#    'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': 'Siniestra llama morada que produce quemaduras. ',
#    'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': 'Fiamme intense di colore viola causano\nuna scottatura al bersaglio.',
#    'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': 'The user shoots a sinister flame at the target to inflict\na burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': '不気味で\u3000怪しい\u3000炎を\u3000放って\n相手を\u3000やけどの\u3000状態に\u3000する。',
#    'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': '放出怪异的火焰，\n从而让对手陷入灼伤状态。',
#    'language': {'name': 'zh-hans',
#     'url': 'https://pokeapi.co/api/v2/language/12/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'flavor_text': 'ぶきみで\u3000あやしい\u3000ほのおを\u3000はなって\nあいてを\u3000やけどの\u3000じょうたいに\u3000する。',
#    'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': '으스스하고 괴상한 불꽃을 쏘아\n상대를 화상 상태로 만든다.',
#    'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': '放出詭異的火焰，\n讓對手陷入灼傷狀態。',
#    'language': {'name': 'zh-hant',
#     'url': 'https://pokeapi.co/api/v2/language/4/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': 'Lance un bouquet de flammes maléfiques à l’ennemi\npour lui infliger une brûlure.',
#    'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': 'Anwender feuert unheimliche Flammen ab, die beim\nZiel Verbrennungen verursachen.',
#    'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': 'Siniestra llama morada que produce quemaduras. ',
#    'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': 'Fiamme sinistre e misteriose causano\nuna scottatura al bersaglio.',
#    'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': 'The user shoots a sinister flame at the target to inflict\na burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': '不気味で\u3000怪しい\u3000炎を\u3000放って\n相手を\u3000やけどの\u3000状態に\u3000する。',
#    'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': '放出怪异的火焰，\n从而让对手陷入灼伤状态。',
#    'language': {'name': 'zh-hans',
#     'url': 'https://pokeapi.co/api/v2/language/12/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'flavor_text': 'The user shoots a sinister flame at the target to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'legends-arceus',
#     'url': 'https://pokeapi.co/api/v2/version-group/24/'}},
#   {'flavor_text': 'The user shoots a sinister flame at the target to inflict a burn.',
#    'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'version_group': {'name': 'scarlet-violet',
#     'url': 'https://pokeapi.co/api/v2/version-group/25/'}}],
#  'generation': {'name': 'generation-iii',
#   'url': 'https://pokeapi.co/api/v2/generation/3/'},
#  'id': 261,
#  'learned_by_pokemon': [{'name': 'charmander',
#    'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'vulpix', 'url': 'https://pokeapi.co/api/v2/pokemon/37/'},
#   {'name': 'ninetales', 'url': 'https://pokeapi.co/api/v2/pokemon/38/'},
#   {'name': 'growlithe', 'url': 'https://pokeapi.co/api/v2/pokemon/58/'},
#   {'name': 'arcanine', 'url': 'https://pokeapi.co/api/v2/pokemon/59/'},
#   {'name': 'ponyta', 'url': 'https://pokeapi.co/api/v2/pokemon/77/'},
#   {'name': 'rapidash', 'url': 'https://pokeapi.co/api/v2/pokemon/78/'},
#   {'name': 'gastly', 'url': 'https://pokeapi.co/api/v2/pokemon/92/'},
#   {'name': 'haunter', 'url': 'https://pokeapi.co/api/v2/pokemon/93/'},
#   {'name': 'gengar', 'url': 'https://pokeapi.co/api/v2/pokemon/94/'},
#   {'name': 'koffing', 'url': 'https://pokeapi.co/api/v2/pokemon/109/'},
#   {'name': 'weezing', 'url': 'https://pokeapi.co/api/v2/pokemon/110/'},
#   {'name': 'magmar', 'url': 'https://pokeapi.co/api/v2/pokemon/126/'},
#   {'name': 'flareon', 'url': 'https://pokeapi.co/api/v2/pokemon/136/'},
#   {'name': 'moltres', 'url': 'https://pokeapi.co/api/v2/pokemon/146/'},
#   {'name': 'mewtwo', 'url': 'https://pokeapi.co/api/v2/pokemon/150/'},
#   {'name': 'mew', 'url': 'https://pokeapi.co/api/v2/pokemon/151/'},
#   {'name': 'cyndaquil', 'url': 'https://pokeapi.co/api/v2/pokemon/155/'},
#   {'name': 'quilava', 'url': 'https://pokeapi.co/api/v2/pokemon/156/'},
#   {'name': 'typhlosion', 'url': 'https://pokeapi.co/api/v2/pokemon/157/'},
#   {'name': 'misdreavus', 'url': 'https://pokeapi.co/api/v2/pokemon/200/'},
#   {'name': 'slugma', 'url': 'https://pokeapi.co/api/v2/pokemon/218/'},
#   {'name': 'magcargo', 'url': 'https://pokeapi.co/api/v2/pokemon/219/'},
#   {'name': 'houndour', 'url': 'https://pokeapi.co/api/v2/pokemon/228/'},
#   {'name': 'houndoom', 'url': 'https://pokeapi.co/api/v2/pokemon/229/'},
#   {'name': 'magby', 'url': 'https://pokeapi.co/api/v2/pokemon/240/'},
#   {'name': 'entei', 'url': 'https://pokeapi.co/api/v2/pokemon/244/'},
#   {'name': 'ho-oh', 'url': 'https://pokeapi.co/api/v2/pokemon/250/'},
#   {'name': 'torchic', 'url': 'https://pokeapi.co/api/v2/pokemon/255/'},
#   {'name': 'combusken', 'url': 'https://pokeapi.co/api/v2/pokemon/256/'},
#   {'name': 'blaziken', 'url': 'https://pokeapi.co/api/v2/pokemon/257/'},
#   {'name': 'shiftry', 'url': 'https://pokeapi.co/api/v2/pokemon/275/'},
#   {'name': 'ralts', 'url': 'https://pokeapi.co/api/v2/pokemon/280/'},
#   {'name': 'kirlia', 'url': 'https://pokeapi.co/api/v2/pokemon/281/'},
#   {'name': 'gardevoir', 'url': 'https://pokeapi.co/api/v2/pokemon/282/'},
#   {'name': 'shedinja', 'url': 'https://pokeapi.co/api/v2/pokemon/292/'},
#   {'name': 'sableye', 'url': 'https://pokeapi.co/api/v2/pokemon/302/'},
#   {'name': 'numel', 'url': 'https://pokeapi.co/api/v2/pokemon/322/'},
#   {'name': 'camerupt', 'url': 'https://pokeapi.co/api/v2/pokemon/323/'},
#   {'name': 'torkoal', 'url': 'https://pokeapi.co/api/v2/pokemon/324/'},
#   {'name': 'altaria', 'url': 'https://pokeapi.co/api/v2/pokemon/334/'},
#   {'name': 'solrock', 'url': 'https://pokeapi.co/api/v2/pokemon/338/'},
#   {'name': 'shuppet', 'url': 'https://pokeapi.co/api/v2/pokemon/353/'},
#   {'name': 'banette', 'url': 'https://pokeapi.co/api/v2/pokemon/354/'},
#   {'name': 'duskull', 'url': 'https://pokeapi.co/api/v2/pokemon/355/'},
#   {'name': 'dusclops', 'url': 'https://pokeapi.co/api/v2/pokemon/356/'},
#   {'name': 'absol', 'url': 'https://pokeapi.co/api/v2/pokemon/359/'},
#   {'name': 'groudon', 'url': 'https://pokeapi.co/api/v2/pokemon/383/'},
#   {'name': 'chimchar', 'url': 'https://pokeapi.co/api/v2/pokemon/390/'},
#   {'name': 'monferno', 'url': 'https://pokeapi.co/api/v2/pokemon/391/'},
#   {'name': 'infernape', 'url': 'https://pokeapi.co/api/v2/pokemon/392/'},
#   {'name': 'drifloon', 'url': 'https://pokeapi.co/api/v2/pokemon/425/'},
#   {'name': 'drifblim', 'url': 'https://pokeapi.co/api/v2/pokemon/426/'},
#   {'name': 'mismagius', 'url': 'https://pokeapi.co/api/v2/pokemon/429/'},
#   {'name': 'spiritomb', 'url': 'https://pokeapi.co/api/v2/pokemon/442/'},
#   {'name': 'magmortar', 'url': 'https://pokeapi.co/api/v2/pokemon/467/'},
#   {'name': 'gallade', 'url': 'https://pokeapi.co/api/v2/pokemon/475/'},
#   {'name': 'dusknoir', 'url': 'https://pokeapi.co/api/v2/pokemon/477/'},
#   {'name': 'froslass', 'url': 'https://pokeapi.co/api/v2/pokemon/478/'},
#   {'name': 'rotom', 'url': 'https://pokeapi.co/api/v2/pokemon/479/'},
#   {'name': 'heatran', 'url': 'https://pokeapi.co/api/v2/pokemon/485/'},
#   {'name': 'giratina-altered',
#    'url': 'https://pokeapi.co/api/v2/pokemon/487/'},
#   {'name': 'darkrai', 'url': 'https://pokeapi.co/api/v2/pokemon/491/'},
#   {'name': 'arceus', 'url': 'https://pokeapi.co/api/v2/pokemon/493/'},
#   {'name': 'victini', 'url': 'https://pokeapi.co/api/v2/pokemon/494/'},
#   {'name': 'tepig', 'url': 'https://pokeapi.co/api/v2/pokemon/498/'},
#   {'name': 'pignite', 'url': 'https://pokeapi.co/api/v2/pokemon/499/'},
#   {'name': 'emboar', 'url': 'https://pokeapi.co/api/v2/pokemon/500/'},
#   {'name': 'pansear', 'url': 'https://pokeapi.co/api/v2/pokemon/513/'},
#   {'name': 'simisear', 'url': 'https://pokeapi.co/api/v2/pokemon/514/'},
#   {'name': 'darumaka', 'url': 'https://pokeapi.co/api/v2/pokemon/554/'},
#   {'name': 'darmanitan-standard',
#    'url': 'https://pokeapi.co/api/v2/pokemon/555/'},
#   {'name': 'yamask', 'url': 'https://pokeapi.co/api/v2/pokemon/562/'},
#   {'name': 'cofagrigus', 'url': 'https://pokeapi.co/api/v2/pokemon/563/'},
#   {'name': 'frillish-male', 'url': 'https://pokeapi.co/api/v2/pokemon/592/'},
#   {'name': 'jellicent-male', 'url': 'https://pokeapi.co/api/v2/pokemon/593/'},
#   {'name': 'litwick', 'url': 'https://pokeapi.co/api/v2/pokemon/607/'},
#   {'name': 'lampent', 'url': 'https://pokeapi.co/api/v2/pokemon/608/'},
#   {'name': 'chandelure', 'url': 'https://pokeapi.co/api/v2/pokemon/609/'},
#   {'name': 'heatmor', 'url': 'https://pokeapi.co/api/v2/pokemon/631/'},
#   {'name': 'larvesta', 'url': 'https://pokeapi.co/api/v2/pokemon/636/'},
#   {'name': 'volcarona', 'url': 'https://pokeapi.co/api/v2/pokemon/637/'},
#   {'name': 'reshiram', 'url': 'https://pokeapi.co/api/v2/pokemon/643/'},
#   {'name': 'fennekin', 'url': 'https://pokeapi.co/api/v2/pokemon/653/'},
#   {'name': 'braixen', 'url': 'https://pokeapi.co/api/v2/pokemon/654/'},
#   {'name': 'delphox', 'url': 'https://pokeapi.co/api/v2/pokemon/655/'},
#   {'name': 'fletchling', 'url': 'https://pokeapi.co/api/v2/pokemon/661/'},
#   {'name': 'fletchinder', 'url': 'https://pokeapi.co/api/v2/pokemon/662/'},
#   {'name': 'talonflame', 'url': 'https://pokeapi.co/api/v2/pokemon/663/'},
#   {'name': 'litleo', 'url': 'https://pokeapi.co/api/v2/pokemon/667/'},
#   {'name': 'pyroar-male', 'url': 'https://pokeapi.co/api/v2/pokemon/668/'},
#   {'name': 'phantump', 'url': 'https://pokeapi.co/api/v2/pokemon/708/'},
#   {'name': 'trevenant', 'url': 'https://pokeapi.co/api/v2/pokemon/709/'},
#   {'name': 'pumpkaboo-average',
#    'url': 'https://pokeapi.co/api/v2/pokemon/710/'},
#   {'name': 'gourgeist-average',
#    'url': 'https://pokeapi.co/api/v2/pokemon/711/'},
#   {'name': 'volcanion', 'url': 'https://pokeapi.co/api/v2/pokemon/721/'},
#   {'name': 'litten', 'url': 'https://pokeapi.co/api/v2/pokemon/725/'},
#   {'name': 'torracat', 'url': 'https://pokeapi.co/api/v2/pokemon/726/'},
#   {'name': 'incineroar', 'url': 'https://pokeapi.co/api/v2/pokemon/727/'},
#   {'name': 'salandit', 'url': 'https://pokeapi.co/api/v2/pokemon/757/'},
#   {'name': 'salazzle', 'url': 'https://pokeapi.co/api/v2/pokemon/758/'},
#   {'name': 'turtonator', 'url': 'https://pokeapi.co/api/v2/pokemon/776/'},
#   {'name': 'mimikyu-disguised',
#    'url': 'https://pokeapi.co/api/v2/pokemon/778/'},
#   {'name': 'lunala', 'url': 'https://pokeapi.co/api/v2/pokemon/792/'},
#   {'name': 'marshadow', 'url': 'https://pokeapi.co/api/v2/pokemon/802/'},
#   {'name': 'blacephalon', 'url': 'https://pokeapi.co/api/v2/pokemon/806/'},
#   {'name': 'cinderace', 'url': 'https://pokeapi.co/api/v2/pokemon/815/'},
#   {'name': 'rolycoly', 'url': 'https://pokeapi.co/api/v2/pokemon/837/'},
#   {'name': 'carkol', 'url': 'https://pokeapi.co/api/v2/pokemon/838/'},
#   {'name': 'coalossal', 'url': 'https://pokeapi.co/api/v2/pokemon/839/'},
#   {'name': 'centiskorch', 'url': 'https://pokeapi.co/api/v2/pokemon/851/'},
#   {'name': 'sinistea', 'url': 'https://pokeapi.co/api/v2/pokemon/854/'},
#   {'name': 'polteageist', 'url': 'https://pokeapi.co/api/v2/pokemon/855/'},
#   {'name': 'cursola', 'url': 'https://pokeapi.co/api/v2/pokemon/864/'},
#   {'name': 'runerigus', 'url': 'https://pokeapi.co/api/v2/pokemon/867/'},
#   {'name': 'drakloak', 'url': 'https://pokeapi.co/api/v2/pokemon/886/'},
#   {'name': 'dragapult', 'url': 'https://pokeapi.co/api/v2/pokemon/887/'},
#   {'name': 'spectrier', 'url': 'https://pokeapi.co/api/v2/pokemon/897/'},
#   {'name': 'fuecoco', 'url': 'https://pokeapi.co/api/v2/pokemon/909/'},
#   {'name': 'crocalor', 'url': 'https://pokeapi.co/api/v2/pokemon/910/'},
#   {'name': 'skeledirge', 'url': 'https://pokeapi.co/api/v2/pokemon/911/'},
#   {'name': 'charcadet', 'url': 'https://pokeapi.co/api/v2/pokemon/935/'},
#   {'name': 'armarouge', 'url': 'https://pokeapi.co/api/v2/pokemon/936/'},
#   {'name': 'ceruledge', 'url': 'https://pokeapi.co/api/v2/pokemon/937/'},
#   {'name': 'scovillain', 'url': 'https://pokeapi.co/api/v2/pokemon/952/'},
#   {'name': 'houndstone', 'url': 'https://pokeapi.co/api/v2/pokemon/972/'},
#   {'name': 'slither-wing', 'url': 'https://pokeapi.co/api/v2/pokemon/988/'},
#   {'name': 'chi-yu', 'url': 'https://pokeapi.co/api/v2/pokemon/1004/'},
#   {'name': 'giratina-origin',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10007/'},
#   {'name': 'rotom-heat', 'url': 'https://pokeapi.co/api/v2/pokemon/10008/'},
#   {'name': 'rotom-wash', 'url': 'https://pokeapi.co/api/v2/pokemon/10009/'},
#   {'name': 'rotom-frost', 'url': 'https://pokeapi.co/api/v2/pokemon/10010/'},
#   {'name': 'rotom-fan', 'url': 'https://pokeapi.co/api/v2/pokemon/10011/'},
#   {'name': 'rotom-mow', 'url': 'https://pokeapi.co/api/v2/pokemon/10012/'},
#   {'name': 'darmanitan-zen',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10017/'},
#   {'name': 'pumpkaboo-small',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10027/'},
#   {'name': 'pumpkaboo-large',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10028/'},
#   {'name': 'pumpkaboo-super',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10029/'},
#   {'name': 'gourgeist-small',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10030/'},
#   {'name': 'gourgeist-large',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10031/'},
#   {'name': 'gourgeist-super',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10032/'},
#   {'name': 'charizard-mega-x',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10034/'},
#   {'name': 'charizard-mega-y',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10035/'},
#   {'name': 'gengar-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10038/'},
#   {'name': 'mewtwo-mega-x', 'url': 'https://pokeapi.co/api/v2/pokemon/10043/'},
#   {'name': 'mewtwo-mega-y', 'url': 'https://pokeapi.co/api/v2/pokemon/10044/'},
#   {'name': 'houndoom-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10048/'},
#   {'name': 'blaziken-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10050/'},
#   {'name': 'gardevoir-mega',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10051/'},
#   {'name': 'banette-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10056/'},
#   {'name': 'absol-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10057/'},
#   {'name': 'sableye-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10066/'},
#   {'name': 'gallade-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10068/'},
#   {'name': 'camerupt-mega', 'url': 'https://pokeapi.co/api/v2/pokemon/10087/'},
#   {'name': 'marowak-alola', 'url': 'https://pokeapi.co/api/v2/pokemon/10115/'},
#   {'name': 'salazzle-totem',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10129/'},
#   {'name': 'mimikyu-busted',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10143/'},
#   {'name': 'mimikyu-totem-disguised',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10144/'},
#   {'name': 'mimikyu-totem-busted',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10145/'},
#   {'name': 'marowak-totem', 'url': 'https://pokeapi.co/api/v2/pokemon/10149/'},
#   {'name': 'weezing-galar', 'url': 'https://pokeapi.co/api/v2/pokemon/10167/'},
#   {'name': 'corsola-galar', 'url': 'https://pokeapi.co/api/v2/pokemon/10173/'},
#   {'name': 'darumaka-galar',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10176/'},
#   {'name': 'darmanitan-galar-standard',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10177/'},
#   {'name': 'darmanitan-galar-zen',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10178/'},
#   {'name': 'yamask-galar', 'url': 'https://pokeapi.co/api/v2/pokemon/10179/'},
#   {'name': 'calyrex-shadow',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10194/'},
#   {'name': 'growlithe-hisui',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10229/'},
#   {'name': 'arcanine-hisui',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10230/'},
#   {'name': 'typhlosion-hisui',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10233/'},
#   {'name': 'zorua-hisui', 'url': 'https://pokeapi.co/api/v2/pokemon/10238/'},
#   {'name': 'zoroark-hisui', 'url': 'https://pokeapi.co/api/v2/pokemon/10239/'},
#   {'name': 'tauros-paldea-blaze-breed',
#    'url': 'https://pokeapi.co/api/v2/pokemon/10251/'}],
#  'machines': [{'machine': {'url': 'https://pokeapi.co/api/v2/machine/240/'},
#    'version_group': {'name': 'lets-go-pikachu-lets-go-eevee',
#     'url': 'https://pokeapi.co/api/v2/version-group/19/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/835/'},
#    'version_group': {'name': 'sword-shield',
#     'url': 'https://pokeapi.co/api/v2/version-group/20/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1212/'},
#    'version_group': {'name': 'diamond-pearl',
#     'url': 'https://pokeapi.co/api/v2/version-group/8/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1213/'},
#    'version_group': {'name': 'platinum',
#     'url': 'https://pokeapi.co/api/v2/version-group/9/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1214/'},
#    'version_group': {'name': 'heartgold-soulsilver',
#     'url': 'https://pokeapi.co/api/v2/version-group/10/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1215/'},
#    'version_group': {'name': 'black-white',
#     'url': 'https://pokeapi.co/api/v2/version-group/11/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1216/'},
#    'version_group': {'name': 'black-2-white-2',
#     'url': 'https://pokeapi.co/api/v2/version-group/14/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1217/'},
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1218/'},
#    'version_group': {'name': 'omega-ruby-alpha-sapphire',
#     'url': 'https://pokeapi.co/api/v2/version-group/16/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1219/'},
#    'version_group': {'name': 'sun-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/17/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1220/'},
#    'version_group': {'name': 'ultra-sun-ultra-moon',
#     'url': 'https://pokeapi.co/api/v2/version-group/18/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/1922/'},
#    'version_group': {'name': 'scarlet-violet',
#     'url': 'https://pokeapi.co/api/v2/version-group/25/'}},
#   {'machine': {'url': 'https://pokeapi.co/api/v2/machine/2120/'},
#    'version_group': {'name': 'the-indigo-disk',
#     'url': 'https://pokeapi.co/api/v2/version-group/27/'}}],
#  'meta': {'ailment': {'name': 'burn',
#    'url': 'https://pokeapi.co/api/v2/move-ailment/4/'},
#   'ailment_chance': 0,
#   'category': {'name': 'ailment',
#    'url': 'https://pokeapi.co/api/v2/move-category/1/'},
#   'crit_rate': 0,
#   'drain': 0,
#   'flinch_chance': 0,
#   'healing': 0,
#   'max_hits': None,
#   'max_turns': None,
#   'min_hits': None,
#   'min_turns': None,
#   'stat_chance': 0},
#  'name': 'will-o-wisp',
#  'names': [{'language': {'name': 'ja-hrkt',
#     'url': 'https://pokeapi.co/api/v2/language/1/'},
#    'name': 'おにび'},
#   {'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'},
#    'name': '도깨비불'},
#   {'language': {'name': 'zh-hant',
#     'url': 'https://pokeapi.co/api/v2/language/4/'},
#    'name': '鬼火'},
#   {'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'},
#    'name': 'Feu Follet'},
#   {'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'},
#    'name': 'Irrlicht'},
#   {'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'},
#    'name': 'Fuego Fatuo'},
#   {'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'},
#    'name': 'Fuocofatuo'},
#   {'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'},
#    'name': 'Will-O-Wisp'},
#   {'language': {'name': 'ja', 'url': 'https://pokeapi.co/api/v2/language/11/'},
#    'name': 'おにび'},
#   {'language': {'name': 'zh-hans',
#     'url': 'https://pokeapi.co/api/v2/language/12/'},
#    'name': '鬼火'}],
#  'past_values': [{'accuracy': 75,
#    'effect_chance': None,
#    'effect_entries': [],
#    'power': None,
#    'pp': None,
#    'type': None,
#    'version_group': {'name': 'x-y',
#     'url': 'https://pokeapi.co/api/v2/version-group/15/'}}],
#  'power': None,
#  'pp': 15,
#  'priority': 0,
#  'stat_changes': [],
#  'super_contest_effect': {'url': 'https://pokeapi.co/api/v2/super-contest-effect/17/'},
#  'target': {'name': 'selected-pokemon',
#   'url': 'https://pokeapi.co/api/v2/move-target/10/'},
#  'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}

# %%
for entry in temp.get("flavor_text_entries", []):
    if entry["language"]["name"] == "en":
        # On nettoie les sauts de ligne bizarres de PokeAPI
        print(entry["flavor_text"].replace('\n', ' '))
        break # On en a trouvé une, on arrête de chercher
# Out:
# An attack that may inflict a burn.

# %%
MOVE_CATEGORY = {
    "unknown" : [0.0, 0.0, 0.0],
    "physical" : [1.0, 0.0, 0.0],
    "special" : [0.0, 1.0, 0.0],
    "status" : [0.0, 0.0, 1.0],
    }

print(MOVE_CATEGORY.get(temp["damage_class"]["name"], ""))
# Out:
# tyty

# %%
print(temp["damage_class"]["name"])
# Out:
# status

# %%
from poke_env.battle import Battle, AbstractBattle

# %%
with open('games\gen9randombattle-2390496115.json') as f:
    temp = json.load(f)

# %%
temp.keys()
# Out:
# dict_keys(['schema_version', 'battle_id', 'format_id', 'metadata', 'players', 'team_revelation', 'turns', 'summary', 'integrity'])

# %%
import pandas as pd


df = pd.read_parquet('parquet_games\\randbats_1.parquet')

print(df.head(0))
# Out:
# Empty DataFrame
# Columns: [id, format, players, log, uploadtime, views, formatid, rating]
# Index: []

# %%
df.head(5)
# Out:
#                             id                 format  \
# 0  gen9randombattle-2405183037  [Gen 9] Random Battle
# 1  gen9randombattle-2405176711  [Gen 9] Random Battle
# 2  gen9randombattle-2405181043  [Gen 9] Random Battle
# 3  gen9randombattle-2405181794  [Gen 9] Random Battle
# 4  gen9randombattle-2405173427  [Gen 9] Random Battle
#
#                      players  \
# 0    [Pikkebaas RDAM, Fexyl]
# 1        [merstach, 33 eels]
# 2       [SirGaglor, UziBoii]
# 3      [fat marmot, muddbud]
# 4  [Octograbber55, Chavarry]
#
#                                                  log  uploadtime  views  \
# 0  |j|☆Pikkebaas RDAM\n|j|☆Fexyl\n|t:|1752880237\...  1752880802     29
# 1  |j|‽merstach\n|j|☆33 eels\n|t:|1752879337\n|ga...  1752879713      1
# 2  |j|☆SirGaglor\n|j|☆UziBoii\n|t:|1752879951\n|g...  1752880495      1
# 3  |badge|p1|silver|gen9randombattle|30-6\n|uhtml...  1752880700      5
# 4  |j|☆Octograbber55\n|j|☆Chavarry\n|t:|175287888...  1752879123      1
#
#            formatid  rating
# 0  gen9randombattle  1154.0
# 1  gen9randombattle  1904.0
# 2  gen9randombattle  1386.0
# 3  gen9randombattle  2405.0
# 4  gen9randombattle  1112.0

# %%
df.iloc[1]["log"]
# Out:
# "|j|‽merstach\n|j|☆33 eels\n|t:|1752879337\n|gametype|singles\n|player|p1|merstach|102|1883\n|player|p2|33 eels|bodybuilderf-gen9|1927\n|gen|9\n|tier|[Gen 9] Random Battle\n|rated|\n|rule|Species Clause: Limit one of each Pokémon\n|rule|HP Percentage Mod: HP is shown in percentages\n|rule|Sleep Clause Mod: Limit one foe put to sleep\n|rule|Illusion Level Mod: Illusion disguises the Pokémon's true level\n|\n|t:|1752879337\n|teamsize|p1|6\n|teamsize|p2|6\n|start\n|switch|p1a: Ludicolo|Ludicolo, L90, M|290/290\n|switch|p2a: Iron Hands|Iron Hands, L79|373/373\n|turn|1\n|inactive|Battle timer is ON: inactive players will automatically lose when time's up. (requested by merstach)\n|inactive|merstach has 120 seconds left.\n|\n|t:|1752879386\n|move|p2a: Iron Hands|Fake Out|p1a: Ludicolo\n|-damage|p1a: Ludicolo|253/290\n|cant|p1a: Ludicolo|flinch\n|\n|upkeep\n|turn|2\n|\n|t:|1752879413\n|switch|p1a: Carbink|Carbink, L90|236/236\n|move|p2a: Iron Hands|Close Combat|p1a: Carbink\n|-damage|p1a: Carbink|151/236\n|-unboost|p2a: Iron Hands|def|1\n|-unboost|p2a: Iron Hands|spd|1\n|\n|-heal|p1a: Carbink|165/236|[from] item: Leftovers\n|upkeep\n|turn|3\n|inactive|33 eels has 120 seconds left.\n|\n|t:|1752879431\n|-end|p2a: Iron Hands|Quark Drive|[silent]\n|switch|p2a: Manaphy|Manaphy, L78|284/284\n|move|p1a: Carbink|Rock Polish|p1a: Carbink\n|-boost|p1a: Carbink|spe|2\n|\n|-heal|p1a: Carbink|179/236|[from] item: Leftovers\n|upkeep\n|turn|4\n|inactive|merstach has 120 seconds left.\n|\n|t:|1752879484\n|-terastallize|p1a: Carbink|Fighting\n|move|p1a: Carbink|Iron Defense|p1a: Carbink\n|-boost|p1a: Carbink|def|2\n|move|p2a: Manaphy|Hydro Pump|p1a: Carbink\n|-damage|p1a: Carbink|109/236\n|\n|-heal|p1a: Carbink|123/236|[from] item: Leftovers\n|upkeep\n|turn|5\n|inactive|33 eels has 120 seconds left.\n|inactive|33 eels has 90 seconds left.\n|\n|t:|1752879529\n|switch|p2a: Comfey|Comfey, L85, F|225/225\n|move|p1a: Carbink|Iron Defense|p1a: Carbink\n|-boost|p1a: Carbink|def|2\n|\n|-heal|p1a: Carbink|137/236|[from] item: Leftovers\n|upkeep\n|turn|6\n|inactive|merstach has 90 seconds left.\n|inactive|merstach has 60 seconds left.\n|\n|t:|1752879602\n|move|p1a: Carbink|Iron Defense|p1a: Carbink\n|-boost|p1a: Carbink|def|2\n|move|p2a: Comfey|Calm Mind|p2a: Comfey\n|-boost|p2a: Comfey|spa|1\n|-boost|p2a: Comfey|spd|1\n|\n|-heal|p1a: Carbink|151/236|[from] item: Leftovers\n|upkeep\n|turn|7\n|inactive|33 eels has 90 seconds left.\n|\n|t:|1752879635\n|move|p2a: Comfey|Draining Kiss|p1a: Carbink\n|-supereffective|p1a: Carbink\n|-damage|p1a: Carbink|65/236\n|move|p1a: Carbink|Body Press|p2a: Comfey\n|-resisted|p2a: Comfey\n|-damage|p2a: Comfey|0 fnt\n|faint|p2a: Comfey\n|\n|-heal|p1a: Carbink|79/236|[from] item: Leftovers\n|upkeep\n|inactive|33 eels has 60 seconds left.\n|\n|t:|1752879659\n|switch|p2a: Manaphy|Manaphy, L78|284/284\n|turn|8\n|inactive|33 eels has 60 seconds left.\n|\n|t:|1752879673\n|-terastallize|p2a: Manaphy|Water\n|move|p1a: Carbink|Body Press|p2a: Manaphy\n|-damage|p2a: Manaphy|0 fnt\n|faint|p2a: Manaphy\n|\n|-heal|p1a: Carbink|93/236|[from] item: Leftovers\n|upkeep\n|inactive|33 eels has 60 seconds left.\n|-message|33 eels forfeited.\n|\n|win|merstach\n|raw|merstach's rating: 1883 &rarr; <strong>1906</strong><br />(+23 for winning)\n|raw|33 eels's rating: 1927 &rarr; <strong>1904</strong><br />(-23 for losing)\n|l|☆33 eels\n|player|p2|\n"

# %%
df["log"][0]
# Out:
# "|j|☆Pikkebaas RDAM\n|j|☆Fexyl\n|t:|1752880237\n|gametype|singles\n|player|p1|Pikkebaas RDAM|bruno|1183\n|player|p2|Fexyl|2|1179\n|gen|9\n|tier|[Gen 9] Random Battle\n|rated|\n|rule|Species Clause: Limit one of each Pokémon\n|rule|HP Percentage Mod: HP is shown in percentages\n|rule|Sleep Clause Mod: Limit one foe put to sleep\n|rule|Illusion Level Mod: Illusion disguises the Pokémon's true level\n|\n|t:|1752880237\n|teamsize|p1|6\n|teamsize|p2|6\n|start\n|switch|p1a: Gastrodon|Gastrodon-East, L86, F|331/331\n|switch|p2a: Lumineon|Lumineon, L93, M|279/279\n|turn|1\n|\n|t:|1752880253\n|move|p2a: Lumineon|Ice Beam|p1a: Gastrodon\n|-damage|p1a: Gastrodon|268/331\n|move|p1a: Gastrodon|Stealth Rock|p2a: Lumineon\n|-sidestart|p2: Fexyl|move: Stealth Rock\n|\n|-heal|p1a: Gastrodon|288/331|[from] item: Leftovers\n|upkeep\n|turn|2\n|\n|t:|1752880264\n|move|p2a: Lumineon|U-turn|p1a: Gastrodon\n|-damage|p1a: Gastrodon|228/331\n|\n|t:|1752880267\n|switch|p2a: Sceptile|Sceptile, L87, M|264/264|[from] U-turn\n|-damage|p2a: Sceptile|231/264|[from] Stealth Rock\n|move|p1a: Gastrodon|Earthquake|p2a: Sceptile\n|-resisted|p2a: Sceptile\n|-damage|p2a: Sceptile|173/264\n|\n|-heal|p1a: Gastrodon|248/331|[from] item: Leftovers\n|upkeep\n|turn|3\n|\n|t:|1752880286\n|-terastallize|p1a: Gastrodon|Poison\n|move|p2a: Sceptile|Swords Dance|p2a: Sceptile\n|-boost|p2a: Sceptile|atk|2\n|move|p1a: Gastrodon|Ice Beam|p2a: Sceptile\n|-supereffective|p2a: Sceptile\n|-damage|p2a: Sceptile|45/264\n|\n|-heal|p1a: Gastrodon|268/331|[from] item: Leftovers\n|upkeep\n|turn|4\n|\n|t:|1752880313\n|move|p2a: Sceptile|Rock Slide|p1a: Gastrodon\n|-damage|p1a: Gastrodon|124/331\n|-damage|p2a: Sceptile|19/264|[from] item: Life Orb\n|move|p1a: Gastrodon|Ice Beam|p2a: Sceptile\n|-supereffective|p2a: Sceptile\n|-damage|p2a: Sceptile|0 fnt\n|faint|p2a: Sceptile\n|\n|-heal|p1a: Gastrodon|144/331|[from] item: Leftovers\n|upkeep\n|\n|t:|1752880342\n|switch|p2a: Lumineon|Lumineon, L93, M|279/279\n|turn|5\n|\n|t:|1752880349\n|move|p2a: Lumineon|Hydro Pump|p1a: Gastrodon\n|-ability|p1a: Gastrodon|Storm Drain|boost\n|-boost|p1a: Gastrodon|spa|1\n|move|p1a: Gastrodon|Earthquake|p2a: Lumineon\n|-damage|p2a: Lumineon|177/279\n|\n|-heal|p1a: Gastrodon|164/331|[from] item: Leftovers\n|upkeep\n|turn|6\n|\n|t:|1752880358\n|move|p2a: Lumineon|Ice Beam|p1a: Gastrodon\n|-damage|p1a: Gastrodon|98/331\n|-status|p1a: Gastrodon|frz\n|cant|p1a: Gastrodon|frz\n|\n|-heal|p1a: Gastrodon|118/331 frz|[from] item: Leftovers\n|upkeep\n|turn|7\n|\n|t:|1752880367\n|move|p2a: Lumineon|Ice Beam|p1a: Gastrodon\n|-damage|p1a: Gastrodon|50/331 frz\n|cant|p1a: Gastrodon|frz\n|\n|-heal|p1a: Gastrodon|70/331 frz|[from] item: Leftovers\n|upkeep\n|turn|8\n|\n|t:|1752880375\n|move|p2a: Lumineon|Ice Beam|p1a: Gastrodon\n|-damage|p1a: Gastrodon|7/331 frz\n|cant|p1a: Gastrodon|frz\n|\n|-heal|p1a: Gastrodon|27/331 frz|[from] item: Leftovers\n|upkeep\n|turn|9\n|\n|t:|1752880410\n|move|p2a: Lumineon|U-turn|p1a: Gastrodon\n|-resisted|p1a: Gastrodon\n|-damage|p1a: Gastrodon|0 fnt\n|faint|p1a: Gastrodon\n|\n|t:|1752880422\n|switch|p2a: Slaking|Slaking, L84, F|389/389|[from] U-turn\n|-damage|p2a: Slaking|341/389|[from] Stealth Rock\n|\n|upkeep\n|\n|t:|1752880444\n|switch|p1a: Arbok|Arbok, L87, F|246/246\n|-ability|p1a: Arbok|Intimidate|boost\n|-unboost|p2a: Slaking|atk|1\n|turn|10\n|\n|t:|1752880474\n|switch|p1a: Wyrdeer|Wyrdeer, L87, F|321/321\n|-ability|p1a: Wyrdeer|Intimidate|boost\n|-unboost|p2a: Slaking|atk|1\n|move|p2a: Slaking|Giga Impact|p1a: Wyrdeer\n|-damage|p1a: Wyrdeer|110/321\n|-mustrecharge|p2a: Slaking\n|\n|-heal|p1a: Wyrdeer|130/321|[from] item: Leftovers\n|upkeep\n|turn|11\n|\n|t:|1752880488\n|switch|p1a: Arbok|Arbok, L87, F|246/246\n|-ability|p1a: Arbok|Intimidate|boost\n|-unboost|p2a: Slaking|atk|1\n|cant|p2a: Slaking|recharge\n|\n|upkeep\n|turn|12\n|\n|t:|1752880510\n|switch|p2a: Victreebel|Victreebel, L90, M|290/290\n|-damage|p2a: Victreebel|254/290|[from] Stealth Rock\n|move|p1a: Arbok|Glare|p2a: Victreebel\n ...

# %%
df['log'][1]
# Out:
# "|j|‽merstach\n|j|☆33 eels\n|t:|1752879337\n|gametype|singles\n|player|p1|merstach|102|1883\n|player|p2|33 eels|bodybuilderf-gen9|1927\n|gen|9\n|tier|[Gen 9] Random Battle\n|rated|\n|rule|Species Clause: Limit one of each Pokémon\n|rule|HP Percentage Mod: HP is shown in percentages\n|rule|Sleep Clause Mod: Limit one foe put to sleep\n|rule|Illusion Level Mod: Illusion disguises the Pokémon's true level\n|\n|t:|1752879337\n|teamsize|p1|6\n|teamsize|p2|6\n|start\n|switch|p1a: Ludicolo|Ludicolo, L90, M|290/290\n|switch|p2a: Iron Hands|Iron Hands, L79|373/373\n|turn|1\n|inactive|Battle timer is ON: inactive players will automatically lose when time's up. (requested by merstach)\n|inactive|merstach has 120 seconds left.\n|\n|t:|1752879386\n|move|p2a: Iron Hands|Fake Out|p1a: Ludicolo\n|-damage|p1a: Ludicolo|253/290\n|cant|p1a: Ludicolo|flinch\n|\n|upkeep\n|turn|2\n|\n|t:|1752879413\n|switch|p1a: Carbink|Carbink, L90|236/236\n|move|p2a: Iron Hands|Close Combat|p1a: Carbink\n|-damage|p1a: Carbink|151/236\n|-unboost|p2a: Iron Hands|def|1\n|-unboost|p2a: Iron Hands|spd|1\n|\n|-heal|p1a: Carbink|165/236|[from] item: Leftovers\n|upkeep\n|turn|3\n|inactive|33 eels has 120 seconds left.\n|\n|t:|1752879431\n|-end|p2a: Iron Hands|Quark Drive|[silent]\n|switch|p2a: Manaphy|Manaphy, L78|284/284\n|move|p1a: Carbink|Rock Polish|p1a: Carbink\n|-boost|p1a: Carbink|spe|2\n|\n|-heal|p1a: Carbink|179/236|[from] item: Leftovers\n|upkeep\n|turn|4\n|inactive|merstach has 120 seconds left.\n|\n|t:|1752879484\n|-terastallize|p1a: Carbink|Fighting\n|move|p1a: Carbink|Iron Defense|p1a: Carbink\n|-boost|p1a: Carbink|def|2\n|move|p2a: Manaphy|Hydro Pump|p1a: Carbink\n|-damage|p1a: Carbink|109/236\n|\n|-heal|p1a: Carbink|123/236|[from] item: Leftovers\n|upkeep\n|turn|5\n|inactive|33 eels has 120 seconds left.\n|inactive|33 eels has 90 seconds left.\n|\n|t:|1752879529\n|switch|p2a: Comfey|Comfey, L85, F|225/225\n|move|p1a: Carbink|Iron Defense|p1a: Carbink\n|-boost|p1a: Carbink|def|2\n|\n|-heal|p1a: Carbink|137/236|[from] item: Leftovers\n|upkeep\n|turn|6\n|inactive|merstach has 90 seconds left.\n|inactive|merstach has 60 seconds left.\n|\n|t:|1752879602\n|move|p1a: Carbink|Iron Defense|p1a: Carbink\n|-boost|p1a: Carbink|def|2\n|move|p2a: Comfey|Calm Mind|p2a: Comfey\n|-boost|p2a: Comfey|spa|1\n|-boost|p2a: Comfey|spd|1\n|\n|-heal|p1a: Carbink|151/236|[from] item: Leftovers\n|upkeep\n|turn|7\n|inactive|33 eels has 90 seconds left.\n|\n|t:|1752879635\n|move|p2a: Comfey|Draining Kiss|p1a: Carbink\n|-supereffective|p1a: Carbink\n|-damage|p1a: Carbink|65/236\n|move|p1a: Carbink|Body Press|p2a: Comfey\n|-resisted|p2a: Comfey\n|-damage|p2a: Comfey|0 fnt\n|faint|p2a: Comfey\n|\n|-heal|p1a: Carbink|79/236|[from] item: Leftovers\n|upkeep\n|inactive|33 eels has 60 seconds left.\n|\n|t:|1752879659\n|switch|p2a: Manaphy|Manaphy, L78|284/284\n|turn|8\n|inactive|33 eels has 60 seconds left.\n|\n|t:|1752879673\n|-terastallize|p2a: Manaphy|Water\n|move|p1a: Carbink|Body Press|p2a: Manaphy\n|-damage|p2a: Manaphy|0 fnt\n|faint|p2a: Manaphy\n|\n|-heal|p1a: Carbink|93/236|[from] item: Leftovers\n|upkeep\n|inactive|33 eels has 60 seconds left.\n|-message|33 eels forfeited.\n|\n|win|merstach\n|raw|merstach's rating: 1883 &rarr; <strong>1906</strong><br />(+23 for winning)\n|raw|33 eels's rating: 1927 &rarr; <strong>1904</strong><br />(-23 for losing)\n|l|☆33 eels\n|player|p2|\n"

# %%
with open('gen9randombattle.json') as f:
    dico = json.load(f)

for role_name, role_data in dico['Darkrai']["roles"].items():
    print(role_data.get("items"))
# Out:
# ['Leftovers', 'Life Orb']

# %%
with open('games\gen9randombattle-2390496115.json') as f:
    temp = json.load(f)
temp.keys()
# Out:
# dict_keys(['schema_version', 'battle_id', 'format_id', 'metadata', 'players', 'team_revelation', 'turns', 'summary', 'integrity'])

# %%
temp["integrity"]
# Out:
# {'validated': True,
#  'issues': [],
#  'sha256_raw_log': '76c63919b08873756c3f792b01146c90',
#  'generation_time_ms': 0}

# %%
import gymnasium as gym
from gymnasium import spaces

class PokemonRandbatsEnv(gym.Env):
    
    def __init__(self):
        self.action_space = spaces.Discrete(14) # 4 Attaques, 4 Attaques mais en terracristalisant, 5 pokemons à switcher, 1 cas autre au cas où

        self.observation_space = spaces.Discrete(138) 
        # =========================================================================
        # OBSERVATION SPACE : gym.spaces.Box(shape=(138,))
        # Vecteur 1D représentant l'état du jeu à un instant T pour l'agent.
        # Les valeurs "inconnues" (surtout pour l'adversaire) sont initialisées à 0.
        # =========================================================================

        # --- BLOC A : Le Pokémon Actif du Joueur (16 dimensions) ---
        # 1.  ID du Pokémon (Entier)
        # 2.  PV restants (Flottant, idéalement normalisé de 0.0 à 1.0)
        # 3.  ID du Statut (0=None, 1=BRN, 2=PAR, etc.)
        # 4.  Modificateur Attaque (-6 à +6)
        # 5.  Modificateur Défense (-6 à +6)
        # 6.  Modificateur Attaque Spéciale (-6 à +6)
        # 7.  Modificateur Défense Spéciale (-6 à +6)
        # 8.  Modificateur Vitesse (-6 à +6)
        # 9.  Modificateur Précision (-6 à +6)
        # 10. Modificateur Esquive (-6 à +6)
        # 11. ID Attaque 1
        # 12. ID Attaque 2
        # 13. ID Attaque 3
        # 14. ID Attaque 4
        # 15. ID Objet (Item)
        # 16. ID Talent (Ability)

        # --- BLOC B : L'Équipe en Réserve du Joueur (5 * 9 = 45 dimensions) ---
        # Pour chacun des 5 Pokémon en attente (Slots 1 à 5) :
        # 1.  ID du Pokémon
        # 2.  PV restants (0.0 à 1.0, 0.0 signifiant K.O.)
        # 3.  ID du Statut
        # 4.  ID Attaque 1
        # 5.  ID Attaque 2
        # 6.  ID Attaque 3
        # 7.  ID Attaque 4
        # 8.  ID Objet
        # 9.  ID Talent

        # --- BLOC C : Le Pokémon Actif Adverse (16 dimensions) ---
        # (Structure identique au Bloc A. L'information cachée vaut 0)
        # 1.  ID du Pokémon adverse
        # 2.  Pourcentage de PV visibles (0.0 à 1.0)
        # 3.  ID du Statut
        # 4-10. Modificateurs de stats visibles (-6 à +6)
        # 11-14. IDs des attaques (0 si non révélée)
        # 15. ID Objet (0 si non révélé/déclenché)
        # 16. ID Talent (0 si non révélé/déclenché)

        # --- BLOC D : Le Terrain & Les Effets Globaux (16 dimensions) ---
        # 1.  ID de la Météo (0=None, 1=Sun, 2=Rain, etc.)
        # 2.  ID du Terrain (0=None, 1=Electric, 2=Grassy, etc.)
        # Effets du côté du JOUEUR :
        # 3.  Picots / Spikes (0, 1, 2, ou 3 rangées)
        # 4.  Pics Toxik / Toxic Spikes (0, 1, ou 2 rangées)
        # 5.  Piège de Roc / Stealth Rock (0 ou 1)
        # 6.  Toile Gluante / Sticky Web (0 ou 1)
        # 7.  Voile Aurore / Aurora Veil (0 ou 1)
        # 8.  Mur Lumière / Light Screen (0 ou 1)
        # 9.  Protection / Reflect (0 ou 1)
        # Effets du côté de l'ADVERSAIRE :
        # 10. Picots / Spikes (0 à 3)
        # 11. Pics Toxik / Toxic Spikes (0 à 2)
        # 12. Piège de Roc / Stealth Rock (0 ou 1)
        # 13. Toile Gluante / Sticky Web (0 ou 1)
        # 14. Voile Aurore / Aurora Veil (0 ou 1)
        # 15. Mur Lumière / Light Screen (0 ou 1)
        # 16. Protection / Reflect (0 ou 1)

        # --- BLOC E : L'Équipe en Réserve Adverse [MÉMOIRE] (5 * 9 = 45 dimensions) ---
        # (Structure identique au Bloc B. Initialisé à 0. Se remplit 
        # progressivement lorsque l'adversaire révèle son équipe).
        # Pour chaque emplacement adverse en attente (Slots 1 à 5) :
        # 1.  ID du Pokémon (0 si inconnu)
        # 2.  PV restants vus lors de son dernier switch (0.0 à 1.0)
        # 3.  ID du Statut (0 si aucun/inconnu)
        # 4-7. IDs des attaques (0 si non révélée)
        # 8.  ID Objet (0 si inconnu)
        # 9.  ID Talent (0 si inconnu)

        # TOTAL = 16 + 45 + 16 + 16 + 45 = 138 dimensions.


    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        

        return observation, info

    def step(self, action):
        # 3. Exécution d'un tour de jeu
        ...
        return observation, reward, terminated, truncated, info
